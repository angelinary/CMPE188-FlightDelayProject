# %% [markdown]
# # 05 — Final Evaluation & Visualization
# **CMPE 188 | Flight Delay Prediction**
#
# Goals:
# - Confusion matrices for best RF and XGBoost models
# - ROC curves + AUC scores (overlaid)
# - Precision-Recall curves
# - Feature importance: XGBoost gain + permutation importance
# - Summary table across all model variants

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc,
    precision_recall_curve
)
from sklearn.inspection import permutation_importance

# TODO: load best tuned models from notebook 04 (or retrain here)

# %% [markdown]
# ## 1. Confusion Matrices

# %%
# TODO: side-by-side ConfusionMatrixDisplay for RF and XGBoost

# %% [markdown]
# ## 2. ROC Curves

# %%
# TODO: overlaid ROC curves for both models, with AUC in legend

# %% [markdown]
# ## 3. Precision-Recall Curves

# %%
# TODO: overlaid PR curves for both models

# %% [markdown]
# ## 4. Feature Importance

# %%
# TODO: XGBoost feature importance (gain) — horizontal bar chart, top 20
# TODO: permutation importance on test set (model-agnostic)

# %% [markdown]
# ## 5. Final Summary Table

# %%
# TODO: DataFrame — model variant | feature set | ROC-AUC | accuracy | precision | recall | F1
